# %% [markdown]
# # Cherry Blossoms!
#
# If we travel back in time, [cherry blossoms](https://en.wikipedia.org/wiki/Cherry_blossom) were once in full bloom! We don't live in Japan or DC, but in non-COVID times we also have the [Brooklyn Botanic Garden's annual festival](https://www.bbg.org/visit/event/sakura_matsuri_2020).
#
# We'll have to make up for it with data-driven cherry blossoms instead. Once upon a time [Data is Plural](https://tinyletter.com/data-is-plural) linked to [a dataset](http://atmenv.envi.osakafu-u.ac.jp/aono/kyophenotemp4/) about when the cherry trees blossom each year. It's completely out of date, but it's quirky in a real nice way so we're sticking with it.
#
# ## 0. Do all of your importing/setup stuff

# %%
import pandas as pd

# %% [markdown]
# ## 1. Read in the file using pandas, and look at the first five rows
#
# * *Tip: You will probably need to pip install something to make this Excel file work!*

# %%
# !pip install xlrd
df = pd.read_excel('KyotoFullFlower7.xls')
# Out:
# Requirement already satisfied: xlrd in /Users/carolinaszv/.pyenv/versions/3.10.3/lib/python3.10/site-packages (2.0.1)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/Users/carolinaszv/.pyenv/versions/3.10.3/bin/python3.10 -m pip install --upgrade pip' command.

# %% [markdown]
# ## 2. Read in the file using pandas CORRECTLY, and look at the first five rows
#
# Hrm, how do your column names look? Read the file in again but this time add **a parameter to make sure your columns look right**. How can you tell pandas to skip rows?
#
# **TIP: The first year should be 801 AD, and it should not have any dates or anything.**

# %%
df = pd.read_excel('KyotoFullFlower7.xls', header=25)
df.head(30)
# Out:
#      AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0   801                        NaN                  NaN          NaN
# 1   802                        NaN                  NaN          NaN
# 2   803                        NaN                  NaN          NaN
# 3   804                        NaN                  NaN          NaN
# 4   805                        NaN                  NaN          NaN
# 5   806                        NaN                  NaN          NaN
# 6   807                        NaN                  NaN          NaN
# 7   808                        NaN                  NaN          NaN
# 8   809                        NaN                  NaN          NaN
# 9   810                        NaN                  NaN          NaN
# 10  811                        NaN                  NaN          NaN
# 11  812                       92.0                401.0          1.0
# 12  813                        NaN                  NaN          NaN
# 13  814                        NaN                  NaN          NaN
# 14  815                      105.0                415.0          1.0
# 15  816                        NaN                  NaN          NaN
# 16  817                        NaN                  NaN          NaN
# 17  818                        NaN                  NaN          NaN
# 18  819                        NaN                  NaN          NaN
# 19  820                        NaN                  NaN          NaN
# 20  821                        NaN                  NaN          NaN
# 21  822                        NaN                  NaN          NaN
# 22  823                        NaN                  NaN          NaN
# 23  824                        NaN                  NaN          NaN
# 24  825                        NaN                  NaN          NaN
# 25  826                        NaN                  NaN          NaN
# 26  827                        NaN                  NaN          NaN
# 27  828                        NaN                  NaN          NaN
# 28  829                        NaN                  NaN          NaN
# 29  830                        NaN                  NaN          NaN
#
#     Data type code Reference Name
# 0              NaN              -
# 1              NaN              -
# 2              NaN              -
# 3              NaN              -
# 4              NaN              -
# 5              NaN              -
# 6              NaN              -
# 7              NaN              -
# 8              NaN              -
# 9              NaN              -
# 10             NaN              -
# 11             2.0     NIHON-KOKI
# 12             NaN              -
# 13             NaN              -
# 14             2.0     NIHON-KOKI
# 15             NaN              -
# 16             NaN              -
# 17             NaN              -
# 18             NaN              -
# 19             NaN              -
# 20             NaN              -
# 21             NaN              -
# 22             NaN              -
# 23             NaN              -
# 24             NaN              -
# 25             NaN              -
# 26             NaN              -
# 27             NaN              -
# 28             NaN              -
# 29             NaN              -

# %% [markdown]
# ## 3. Look at the final five rows of the data

# %%
df.tail(5)
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#       Data type code          Reference Name
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)

# %% [markdown]
# ## 4. Add some NaN values

# %% [markdown]
# It looks like you should have NaN/missing values in the beginning of the dataset under "Reference name." Read in the file *one more time*, this time making sure all of those missing reference names actually show up as `NaN` instead of `-`.
#
# * *Tip: it's another open with reading in the file!*

# %%
df = pd.read_excel('KyotoFullFlower7.xls', header=25, na_values='-')
df.head(30)
# Out:
#      AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0   801                        NaN                  NaN          NaN
# 1   802                        NaN                  NaN          NaN
# 2   803                        NaN                  NaN          NaN
# 3   804                        NaN                  NaN          NaN
# 4   805                        NaN                  NaN          NaN
# 5   806                        NaN                  NaN          NaN
# 6   807                        NaN                  NaN          NaN
# 7   808                        NaN                  NaN          NaN
# 8   809                        NaN                  NaN          NaN
# 9   810                        NaN                  NaN          NaN
# 10  811                        NaN                  NaN          NaN
# 11  812                       92.0                401.0          1.0
# 12  813                        NaN                  NaN          NaN
# 13  814                        NaN                  NaN          NaN
# 14  815                      105.0                415.0          1.0
# 15  816                        NaN                  NaN          NaN
# 16  817                        NaN                  NaN          NaN
# 17  818                        NaN                  NaN          NaN
# 18  819                        NaN                  NaN          NaN
# 19  820                        NaN                  NaN          NaN
# 20  821                        NaN                  NaN          NaN
# 21  822                        NaN                  NaN          NaN
# 22  823                        NaN                  NaN          NaN
# 23  824                        NaN                  NaN          NaN
# 24  825                        NaN                  NaN          NaN
# 25  826                        NaN                  NaN          NaN
# 26  827                        NaN                  NaN          NaN
# 27  828                        NaN                  NaN          NaN
# 28  829                        NaN                  NaN          NaN
# 29  830                        NaN                  NaN          NaN
#
#     Data type code Reference Name
# 0              NaN            NaN
# 1              NaN            NaN
# 2              NaN            NaN
# 3              NaN            NaN
# 4              NaN            NaN
# 5              NaN            NaN
# 6              NaN            NaN
# 7              NaN            NaN
# 8              NaN            NaN
# 9              NaN            NaN
# 10             NaN            NaN
# 11             2.0     NIHON-KOKI
# 12             NaN            NaN
# 13             NaN            NaN
# 14             2.0     NIHON-KOKI
# 15             NaN            NaN
# 16             NaN            NaN
# 17             NaN            NaN
# 18             NaN            NaN
# 19             NaN            NaN
# 20             NaN            NaN
# 21             NaN            NaN
# 22             NaN            NaN
# 23             NaN            NaN
# 24             NaN            NaN
# 25             NaN            NaN
# 26             NaN            NaN
# 27             NaN            NaN
# 28             NaN            NaN
# 29             NaN            NaN

# %% [markdown]
# ## 5. What reference is the most commonly used when figuring out cherry blossom flowering dates?
#
# If the first result is `"-"`, you need to redo the last question.

# %%
df.columns = df.columns.str.lower().str.replace(" ","_").str.replace("-","_").str.replace("(","").str.replace(")","")
df.reference_name.value_counts()
# Out:
# /var/folders/q4/0833zmdx34l430n2zgb4ybh40000gn/T/ipykernel_77675/3275984310.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.lower().str.replace(" ","_").str.replace("-","_").str.replace("(","").str.replace(")","")
# /var/folders/q4/0833zmdx34l430n2zgb4ybh40000gn/T/ipykernel_77675/3275984310.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.lower().str.replace(" ","_").str.replace("-","_").str.replace("(","").str.replace(")","")
# NEWS-PAPER(ARASHIYAMA)        94
# SUGIURAKE-NIKKI               38
# MYOHOIN-HINAMIKI              32
# OYUDONONO-UENO-NIKKI          26
# OYUDONONO-UENO-NIKKI [EDA]    21
#                               ..
# GONARAIN-GYOSEI-BASSHO         1
# MORIMITSU-KOKI                 1
# SANKAIKI                       1
# TSUKIMOUDE-WAKASHU(PART-3)     1
# NEWS-PAPET(DAIGO-JI)           1
# Name: reference_name, Length: 222, dtype: int64

# %% [markdown]
# ## 6. Filter the list to only include columns where the `Full-flowering date (DOY)` is not missing

# %%
df = df.dropna(subset=['full_flowering_date_doy'])

# %% [markdown]
# ## 6.5 Confirm you now have 827 rows

# %%
df.shape
# Out:
# (827, 6)

# %% [markdown]
# ## 7. Make a histogram of the full-flowering date

# %%
df.full_flowering_date_doy.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 8. Make another histogram of the full-flowering date, but with 39 bins instead of 10

# %%
df.full_flowering_date_doy.hist(bins=39)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 9. What's the average number of days it takes for the flowers to blossom? And how many records do we have?
#
# Answer these both with one line of code.

# %%
df.full_flowering_date_doy.describe()
#We have 827 records and it takes about 104-105 days for the flowers to blossom
# Out:
# count    827.000000
# mean     104.540508
# std        6.407036
# min       86.000000
# 25%      100.000000
# 50%      105.000000
# 75%      109.000000
# max      124.000000
# Name: full_flowering_date_doy, dtype: float64

# %% [markdown]
# ## 10. What's the average days into the year cherry flowers normally blossomed before 1900?

# %%
df.query("ad < 1900").full_flowering_date_doy.mean()
# Out:
# 105.20728291316527

# %% [markdown]
# ## 11. How about after 1900?

# %%
df.query("ad > 1900").full_flowering_date_doy.mean()
# Out:
# 100.3125

# %% [markdown]
# ## 12. How many times was our data from a title in Japanese poetry?
#
# You'll need to read the documentation inside of the Excel file.

# %%
df[df["data_type_code"] == 4].shape
# Out:
# (39, 6)

# %% [markdown]
# ## 13. Display the rows where our data was from a title in Japanese poetry

# %%
df[df["data_type_code"] == 4]
# Out:
#         ad  full_flowering_date_doy  full_flowering_date  source_code  \
# 90     891                    109.0                419.0          5.0
# 94     895                    104.0                414.0          5.0
# 95     896                    104.0                413.0          5.0
# 122    923                    104.0                414.0          5.0
# 154    955                     89.0                330.0          5.0
# 168    969                     98.0                408.0          5.0
# 206   1007                    106.0                416.0          5.0
# 232   1033                    102.0                412.0          5.0
# 235   1036                    104.0                413.0          5.0
# 259   1060                    108.0                417.0          5.0
# 260   1061                     92.0                402.0          6.0
# 283   1084                    120.0                429.0          5.0
# 294   1095                    100.0                410.0          5.0
# 381   1182                    104.0                414.0          6.0
# 389   1190                    112.0                422.0          5.0
# 400   1201                     96.0                406.0          5.0
# 415   1216                    101.0                410.0          5.0
# 418   1219                    101.0                411.0          5.0
# 420   1221                     99.0                409.0          5.0
# 422   1223                    116.0                426.0          5.0
# 435   1236                     87.0                327.0          7.0
# 464   1265                     98.0                408.0          6.0
# 467   1268                    103.0                412.0          6.0
# 468   1269                    100.0                410.0          3.0
# 470   1271                    100.0                410.0          5.0
# 488   1289                    107.0                417.0          3.0
# 500   1301                     95.0                405.0          4.0
# 523   1324                     98.0                407.0          5.0
# 529   1330                    108.0                418.0          7.0
# 646   1447                    111.0                421.0          3.0
# 652   1453                    107.0                417.0          3.0
# 653   1454                    105.0                415.0          3.0
# 673   1474                     98.0                408.0          3.0
# 733   1534                    108.0                418.0          3.0
# 791   1592                     98.0                407.0          4.0
# 839   1640                    103.0                412.0          3.0
# 860   1661                     93.0                403.0          7.0
# 1045  1846                     98.0                408.0          4.0
# 1062  1863                    118.0                428.0          4.0
#
#       data_type_code              reference_name
# 90               4.0                NIHONKIRYAKU
# 94               4.0                NIHONKIRYAKU
# 95               4.0     NIPPON-SANDAI-JITSUROKU
# 122              4.0          ZOKU-KOKIN-WAKASHU
# 154              4.0                     SHUISHO
# 168              4.0                NIHONKIRYAKU
# 206              4.0              MIDO-KAMPAKUKI
# 232              4.0                NIHONKIRYAKU
# 235              4.0                NIHONKIRYAKU
# 259              4.0         SHIN-SENZAI-WAKASHU
# 260              4.0                MOROZANE-SHU
# 283              4.0          ZOKU-GOSEN-WAKASHU
# 294              4.0                     CHUYUKI
# 381              4.0  TSUKIMOUDE-WAKASHU(PART-3)
# 389              4.0                SHUGYOKU-SHU
# 400              4.0           INOKUMA-KAMPAKUKI
# 415              4.0            JUNTOKUIN-GYOSHU
# 418              4.0            JUNTOKUIN-GYOSHU
# 420              4.0                   SHUI-GUSO
# 422              4.0              MITSUTSUNE-SHU
# 435              4.0              SHIIBA-WAKASHU
# 464              4.0                  TAMEIE-SHU
# 467              4.0                  TAMEIE-SHU
# 468              4.0               ZOKU-SHIGUSHO
# 470              4.0         DAINAGON-TAMEIE-SHU
# 488              4.0         NAKANOTSUKASA-NIKKI
# 500              4.0                SANEMI-KYOKI
# 523              4.0        HANAZONOTENNO-SHINKI
# 529              4.0               RINEI-WAKASHU
# 646              4.0                    SOKONSHU
# 652              4.0                    SOKONSHU
# 653              4.0                    SOKONSHU
# 673              4.0              ENROKUCHOKASHU
# 733              4.0      GONARAIN-GYOSEI-BASSHO
# 791              4.0             TOKITSUNE-KYOKI
# 839              4.0                  KYOHAKUSHU
# 860              4.0         BURUI-GENYO-WAKASHU
# 1045             4.0                  TEIEN-EISO
# 1062             4.0                  YATAKA-SHU

# %% [markdown]
# ## 14. Graph the full-flowering date (DOY) over time

# %%
df.plot(x="ad",y="full_flowering_date_doy")
# Out:
# <AxesSubplot:xlabel='ad'>

# %% [markdown]
# ## 15. Smooth out the graph
#
# It's so jagged! You can use `df.rolling` to calculate a rolling average.
#
# The following code calculates a **10-year mean**, using the `AD` column as the anchor. If there aren't 20 samples to work with in a row, it'll accept down to 5. Neat, right?
#
# (We're only looking at the final 5)

# %%
df.rolling(10, on='ad', min_periods=5)['full_flowering_date_doy'].mean().tail()
# Out:
# 1210    95.9
# 1211    96.9
# 1212    96.4
# 1213    96.6
# 1214    96.0
# Name: full_flowering_date_doy, dtype: float64

# %% [markdown]
# Use the code above to create a new column called `rolling_date` in our dataset. It should be the 20-year rolling average of the flowering date. Then plot it, with the year on the x axis and the day of the year on the y axis.
#
# Try adding `ylim=(80, 120)` to your `.plot` command to make things look a little less dire.

# %%
df['rolling_date'] = df.rolling(20, on='ad', min_periods=5)['full_flowering_date_doy'].mean()
df.plot(x="ad", y="rolling_date" , ylim=(80,120))
# Out:
# <AxesSubplot:xlabel='ad'>

# %% [markdown]
# ## 16. Add a month column
#
# Right now the "Full-flowering date" column is pretty rough. It uses numbers like '402' to mean "April 2nd" and "416" to mean "April 16th." Let's make a column to explain what month it happened in.
#
# * Every row that happened in April should have 'April' in the `month` column.
# * Every row that happened in March should have 'March' as the `month` column.
# * Every row that happened in May should have 'May' as the `month` column.
#
# There are **at least two ways to do this.**
#
# #### WAY ONE: The bad-yet-simple way
#
# If you don't want to use `pd.to_datetime`, you can use this as an sample for updating March. It finds everything with a date less than 400 and assigns `March` to the `month` column:
#
# ```python
# df.loc[df['Full-flowering date'] < 400, 'month'] = 'March'
# ```
#
# #### WAY TWO: The good-yet-complicated way
#
# * When you use `pd.to_datetime`, if pandas doesn't figure it out automatically you can also pass a `format=` argument that explains what the format is of the datetime. You use [the codes here](https://strftime.org/) to mark out where the days, months, etc are. For example, `2020-04-09` would be converted using `pd.to_datetime(df.colname, "format='%Y-%m-%d")`.
# * `errors='coerce'` will return `NaN` for missing values. By default it just yells "I don't know what to do!!!"
# * And remember how we used `df.date_column.dt.month` to get the number of the month? For the name, you use `dt.strftime` (string-formatted-time), and pass it [the same codes](https://strftime.org/) to tell it what to do. For example, `df.date_column.dt.strftime("%Y-%m-%d")` would give you `"2020-04-09"`.

# %%
#df['month'] = pd.to_datetime(df.full_flowering_date, format='%m%d', errors='coerce').dt.month_name()
df['month'] = pd.to_datetime(df.full_flowering_date, format='%m%d', errors='coerce').dt.strftime('%B')
df.sample(5)
# Out:
#        ad  full_flowering_date_doy  full_flowering_date  source_code  \
# 463  1264                    103.0                412.0          5.0
# 767  1568                    106.0                415.0          3.0
# 325  1126                    108.0                418.0          4.0
# 997  1798                    110.0                420.0          3.0
# 514  1315                    111.0                421.0          3.0
#
#      data_type_code   reference_name  rolling_date  month
# 463             2.0    ZOKU-SHIGUSHO        103.35  April
# 767             2.0        ATOKAGAMI        106.65  April
# 325             2.0  DAIGOJI-ZATSUYO        105.05  April
# 997             1.0  SUGIURAKE-NIKKI        104.95  April
# 514             2.0    ZOKU-SHIGUSHO        103.70  April

# %% [markdown]
# ## 17. Using your new column, how many blossomings happened in each month?

# %%
df.month.value_counts()
# Out:
# April    814
# March     10
# May        3
# Name: month, dtype: int64

# %% [markdown]
# ## 18. Make a bar graph of how many blossomings happened in each month.

# %%
df.month.value_counts().plot(kind="barh", figsize=(15,5), title="How many blossomings happened each month")
# Out:
# <AxesSubplot:title={'center':'How many blossomings happened each month'}>

# %% [markdown]
# ## 19. Adding a day-of-month column
#
# Now we're going to add a new column called `day_of_month.`
#
# *Tip: If you didn't drop the rows missing full-flowering dates earlier, it will yell at you about missing data. Go back up and fix Number 6!*

# %%
df['day_of_month'] = pd.to_datetime(df.full_flowering_date, format='%m%d', errors='coerce').dt.strftime('%d')
df.sample(5)
# Out:
#         ad  full_flowering_date_doy  full_flowering_date  source_code  \
# 430   1231                    101.0                411.0          4.0
# 1140  1941                    100.0                410.0          4.0
# 597   1398                    106.0                416.0          4.0
# 926   1727                    112.0                422.0          3.0
# 1188  1989                     93.0                403.0          3.0
#
#       data_type_code                  reference_name  rolling_date  month  \
# 430              1.0                        MINKEIKI        104.95  April
# 1140             0.0  KEIHAN RAILWAY ADV(ARASHIYAMA)        104.10  April
# 597              2.0                         GEIYOKI        102.05  April
# 926              2.0                           KAIKI        106.05  April
# 1188             0.0          NEWS-PAPER(ARASHIYAMA)         99.50  April
#
#      day_of_month
# 430            11
# 1140           10
# 597            16
# 926            22
# 1188           03

# %% [markdown]
# ## 20. Adding a date column
#
# If you don't have a nice-looking date column yet, take the `'month'` and `'day_of_month'` columns and combine them in order to create a new column called `'date'`. By "nice looking," I mean it should say something like `April 11`.
#
# * Instead of using the two existing columns, you could learn to use `.dt.strftime` as mentioned above.

# %%
df['date'] = pd.to_datetime(df.full_flowering_date, format='%m%d', errors='coerce').dt.strftime('%B %d')
df.sample(5)
# Out:
#         ad  full_flowering_date_doy  full_flowering_date  source_code  \
# 216   1017                     99.0                409.0          3.0
# 624   1425                     98.0                408.0          3.0
# 578   1379                    103.0                413.0          3.0
# 1078  1879                    102.0                412.0          3.0
# 188    989                    100.0                410.0          4.0
#
#       data_type_code         reference_name  rolling_date  month day_of_month  \
# 216              2.0         MIDO-KAMPAKUKI        104.00  April           09
# 624              1.0  KANMON-GYOKI(FUSHIMI)        101.15  April           08
# 578              1.0                GUKANKI        104.55  April           13
# 1078             2.0        SUGIURAKE-NIKKI        105.35  April           12
# 188              2.0                SHOYUKI        101.00  April           10
#
#           date
# 216   April 09
# 624   April 08
# 578   April 13
# 1078  April 12
# 188   April 10

# %% [markdown]
# ## 21. What day of the week do cherry blossoms like to blossom on?
#
# Do they get the weekends off?

# %%
df['ad'] = pd.to_datetime(df.ad, format='%Y')
df.ad
#Just kidding -- just found out Soma said to skip this because pandas can't handle years this far back
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:510, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     509 try:
# --> 510     values, tz = conversion.datetime_to_datetime64(arg)
#     511     dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# File pandas/_libs/tslibs/conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'int'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [361], in <cell line: 1>()
# ----> 1 df['ad'] = pd.to_datetime(df.ad, format='%Y')
#       2 df.ad
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1051, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1049         result = arg.map(cache_array)
#    1050     else:
# -> 1051         values = convert_listlike(arg._values, format)
#    1052         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1053 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:394, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     391         format = None
#     393 if format is not None:
# --> 394     res = _to_datetime_with_format(
#     395         arg, orig_arg, name, tz, format, exact, errors, infer_datetime_format
#     396     )
#     397     if res is not None:
#     398         return res
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:514, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     512     return DatetimeIndex._simple_new(dta, name=name)
#     513 except (ValueError, TypeError):
# --> 514     raise err
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:501, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     498             return _box_as_indexlike(result, utc=utc, name=name)
#     500     # fallback
# --> 501     res = _array_strptime_with_fallback(
#     502         arg, name, tz, fmt, exact, errors, infer_datetime_format
#     503     )
#     504     return res
#     506 except ValueError as err:
#     507     # Fallback to try to convert datetime objects if timezone-aware
#     508     #  datetime objects are found without passing `utc=True`
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:437, in _array_strptime_with_fallback(arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     434 utc = tz == "utc"
#     436 try:
# --> 437     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors)
#     438     if "%Z" in fmt or "%z" in fmt:
#     439         return _return_parsed_timezone_results(result, timezones, tz, name)
#
# File pandas/_libs/tslibs/strptime.pyx:150, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data '812' does not match format '%Y' (match)

# %% [markdown]
# # YOU ARE DONE.
#
# And **incredible.**
